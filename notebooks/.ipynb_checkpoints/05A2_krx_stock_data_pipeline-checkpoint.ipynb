# %%
# 05A2. KRX Stock Data Pipeline

# 목적: KRX 공식 Open API를 이용한 개별 종목 일별시장 데이터 구축

# 수집 대상:
# - KOSPI
# - KOSDAQ
# - OHLC
# - Volume
# - Trading Value
# - Market Cap

# 현재 상태: KRX IP 제한으로 API 호출 일시 보류

# 중요:
# - 기존 KRX300 Membership 데이터는 다시 수집하지 않음
# - API 정상화 후 하루치 조회부터 검증
# - 장기간 반복 호출은 검증 전 실행하지 않음
